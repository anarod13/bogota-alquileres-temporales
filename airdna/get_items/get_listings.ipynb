# %%
import json
import pandas as pd
from pathlib import Path

def parse_listing_json(file_path, submarket):
    with open(file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    listings = data['payload']['listings']

    df_data = []
    for listing in listings:
        row = {k: v for k, v in listing.items() if k != 'images'}
        if 'location' in row and isinstance(row['location'], dict):
            row['lat'] = row['location'].get('lat')
            row['lng'] = row['location'].get('lng')
            del row['location']
        df_data.append(row)


    df = pd.DataFrame(df_data)
    df['submarket'] = submarket    
    print(f"Loaded {len(df)} listings")
    print(f"\nColumns: {list(df.columns)}")
    print(f"\nDataFrame shape: {df.shape}")
    return df

# %%
def list_files_with_prefix_store_as_csv(prefix, folder_path="../sources/listings/"):
    
    folder = Path(folder_path)
    if not folder.exists():
        print(f"Folder {folder_path} does not exist")
        return []
    
    matching_files = [f.name for f in folder.iterdir() if f.is_file() and f.name.startswith(prefix)]
    matching_files.sort()
    
    print(f"Found {len(matching_files)} files starting with '{prefix}' in {folder_path}:")
    for file in matching_files:
        print(f"  - {file}")
    
    all_dfs = []
    for file in matching_files:
        df = parse_listing_json(f"../sources/listings/{file}", prefix)
        all_dfs.append(df)
        print(f"Loaded {len(df)} listings from {file}")
    
    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        output_path = f"../cleaned/listings/{prefix}.csv"
        combined_df.to_csv(output_path, index=False)
        print(f"\nConcatenated {len(all_dfs)} files into single CSV")
        print(f"Total listings: {len(combined_df)}")
        print(f"Saved to {output_path}")
    else:
        print("No data to save")
    
    return matching_files

# %%
localidades = pd.read_csv("../cleaned/localidades.csv")
localidades_ids = localidades['id'].tolist()
localidades_ids


for localidad in localidades_ids:
    list_files_with_prefix_store_as_csv(str(localidad))
# Out:
# Found 62 files starting with '147956' in ../sources/listings/:
#   - 147956_0.json
#   - 147956_100.json
#   - 147956_1000.json
#   - 147956_1100.json
#   - 147956_1200.json
#   - 147956_1300.json
#   - 147956_1400.json
#   - 147956_1500.json
#   - 147956_1600.json
#   - 147956_1700.json
#   - 147956_1800.json
#   - 147956_1900.json
#   - 147956_200.json
#   - 147956_2000.json
#   - 147956_2100.json
#   - 147956_2200.json
#   - 147956_2300.json
#   - 147956_2400.json
#   - 147956_2500.json
#   - 147956_2600.json
#   - 147956_2700.json
#   - 147956_2800.json
#   - 147956_2900.json
#   - 147956_3000.json
#   - 147956_3100.json
#   - 147956_3200.json
#   - 147956_3300.json
#   - 147956_3400.json
#   - 147956_3500.json
#   - 147956_3600.json
#   - 147956_3700.json
#   - 147956_3800.json
#   - 147956_3900.json
#   - 147956_400.json
#   - 147956_4000.json
#   - 147956_4100.json
#   - 147956_4200.json
#   - 147956_4300.json
#   - 147956_4400.json
#   - 147956_4500.json
#   - 147956_4600.json
#   - 147956_4700.json
#   - 147956_4800.json
#   - 147956_4900.json
#   - 147956_500.json
#   - 147956_5000.json
#   - 147956_5100.json
#   - 147956_5200.json
#   - 147956_5300.json
#   - 147956_5400.json
#   - 147956_5500.json
#   - 147956_5600.json
#   - 147956_5700.json
#   - 147956_5800.json
#   - 147956_5900.json
#   - 147956_600.json
#   - 147956_6000.json
#   - 147956_6100.json
#   - 147956_6200.json
#   - 147956_700.json
#   - 147956_800.json
#   - 147956_900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_6000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_6100.json
# Loaded 60 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (60, 22)
# Loaded 60 listings from 147956_6200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_900.json
#
# Concatenated 62 files into single CSV
# Total listings: 6160
# Saved to ../cleaned/listings/147956.csv
# Found 13 files starting with '147957' in ../sources/listings/:
#   - 147957_0.json
#   - 147957_100.json
#   - 147957_1000.json
#   - 147957_1200.json
#   - 147957_1300.json
#   - 147957_200.json
#   - 147957_300.json
#   - 147957_400.json
#   - 147957_500.json
#   - 147957_600.json
#   - 147957_700.json
#   - 147957_800.json
#   - 147957_900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_1000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_1200.json
# Loaded 34 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (34, 22)
# Loaded 34 listings from 147957_1300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_900.json
#
# Concatenated 13 files into single CSV
# Total listings: 1234
# Saved to ../cleaned/listings/147957.csv
# Found 81 files starting with '184380' in ../sources/listings/:
#   - 184380_0.json
#   - 184380_100.json
#   - 184380_1000.json
#   - 184380_1100.json
#   - 184380_1200.json
#   - 184380_1300.json
#   - 184380_1400.json
#   - 184380_1600.json
#   - 184380_1700.json
#   - 184380_1800.json
#   - 184380_1900.json
#   - 184380_200.json
#   - 184380_2000.json
#   - 184380_2100.json
#   - 184380_2200.json
#   - 184380_2300.json
#   - 184380_2400.json
#   - 184380_2500.json
#   - 184380_2600.json
#   - 184380_2700.json
#   - 184380_2800.json
#   - 184380_2900.json
#   - 184380_300.json
#   - 184380_3000.json
#   - 184380_3100.json
#   - 184380_3200.json
#   - 184380_3300.json
#   - 184380_3400.json
#   - 184380_3500.json
#   - 184380_3600.json
#   - 184380_3700.json
#   - 184380_3800.json
#   - 184380_3900.json
#   - 184380_400.json
#   - 184380_4000.json
#   - 184380_4100.json
#   - 184380_4200.json
#   - 184380_4300.json
#   - 184380_4400.json
#   - 184380_4500.json
#   - 184380_4600.json
#   - 184380_4700.json
#   - 184380_4800.json
#   - 184380_4900.json
#   - 184380_500.json
#   - 184380_5000.json
#   - 184380_5100.json
#   - 184380_5200.json
#   - 184380_5300.json
#   - 184380_5400.json
#   - 184380_5500.json
#   - 184380_5600.json
#   - 184380_5700.json
#   - 184380_5800.json
#   - 184380_5900.json
#   - 184380_600.json
#   - 184380_6000.json
#   - 184380_6100.json
#   - 184380_6200.json
#   - 184380_6300.json
#   - 184380_6400.json
#   - 184380_6500.json
#   - 184380_6600.json
#   - 184380_6700.json
#   - 184380_6800.json
#   - 184380_6900.json
#   - 184380_700.json
#   - 184380_7000.json
#   - 184380_7100.json
#   - 184380_7200.json
#   - 184380_7300.json
#   - 184380_7400.json
#   - 184380_7500.json
#   - 184380_7600.json
#   - 184380_7700.json
#   - 184380_7800.json
#   - 184380_7900.json
#   - 184380_800.json
#   - 184380_8000.json
#   - 184380_8100.json
#   - 184380_900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_300.json
# Loaded 100 listings
#
# ...
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_8000.json
# Loaded 17 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (17, 22)
# Loaded 17 listings from 184380_8100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_900.json
#
# Concatenated 81 files into single CSV
# Total listings: 8017
# Saved to ../cleaned/listings/184380.csv
# Found 7 files starting with '187616' in ../sources/listings/:
#   - 187616_0.json
#   - 187616_100.json
#   - 187616_200.json
#   - 187616_300.json
#   - 187616_400.json
#   - 187616_500.json
#   - 187616_600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_500.json
# Loaded 60 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (60, 22)
# Loaded 60 listings from 187616_600.json
#
# Concatenated 7 files into single CSV
# Total listings: 660
# Saved to ../cleaned/listings/187616.csv
# Found 5 files starting with '248979' in ../sources/listings/:
#   - 248979_0.json
#   - 248979_100.json
#   - 248979_200.json
#   - 248979_300.json
#   - 248979_400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 248979_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 248979_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 248979_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 248979_300.json
# Loaded 59 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (59, 22)
# Loaded 59 listings from 248979_400.json
#
# Concatenated 5 files into single CSV
# Total listings: 459
# Saved to ../cleaned/listings/248979.csv
# Found 2 files starting with '250564' in ../sources/listings/:
#   - 250564_0.json
#   - 250564_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 250564_0.json
# Loaded 54 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (54, 22)
# Loaded 54 listings from 250564_100.json
#
# Concatenated 2 files into single CSV
# Total listings: 154
# Saved to ../cleaned/listings/250564.csv

# %%
def list_files_with_prefix(prefix, folder_path="../sources/listings/"):
    
    folder = Path(folder_path)
    if not folder.exists():
        print(f"Folder {folder_path} does not exist")
        return []
    
    matching_files = [f.name for f in folder.iterdir() if f.is_file() and f.name.startswith(prefix)]
    matching_files.sort()
    
    print(f"Found {len(matching_files)} files starting with '{prefix}' in {folder_path}:")
    for file in matching_files:
        print(f"  - {file}")
    all_dfs = pd.DataFrame()
    
    for file in matching_files:
        df = parse_listing_json(f"../sources/listings/{file}", prefix)
        all_dfs = pd.concat([all_dfs, df], ignore_index=True)
        print(f"Loaded {len(df)} listings from {file}")
    return all_dfs

# %%
combined_df = pd.DataFrame()
for localidad in localidades_ids:
    df = list_files_with_prefix(str(localidad))
    combined_df = pd.concat([combined_df, df], ignore_index=True)

combined_df.to_csv("../cleaned/all_listings.csv", index=False)

len(combined_df)
# Out:
# Found 62 files starting with '147956' in ../sources/listings/:
#   - 147956_0.json
#   - 147956_100.json
#   - 147956_1000.json
#   - 147956_1100.json
#   - 147956_1200.json
#   - 147956_1300.json
#   - 147956_1400.json
#   - 147956_1500.json
#   - 147956_1600.json
#   - 147956_1700.json
#   - 147956_1800.json
#   - 147956_1900.json
#   - 147956_200.json
#   - 147956_2000.json
#   - 147956_2100.json
#   - 147956_2200.json
#   - 147956_2300.json
#   - 147956_2400.json
#   - 147956_2500.json
#   - 147956_2600.json
#   - 147956_2700.json
#   - 147956_2800.json
#   - 147956_2900.json
#   - 147956_3000.json
#   - 147956_3100.json
#   - 147956_3200.json
#   - 147956_3300.json
#   - 147956_3400.json
#   - 147956_3500.json
#   - 147956_3600.json
#   - 147956_3700.json
#   - 147956_3800.json
#   - 147956_3900.json
#   - 147956_400.json
#   - 147956_4000.json
#   - 147956_4100.json
#   - 147956_4200.json
#   - 147956_4300.json
#   - 147956_4400.json
#   - 147956_4500.json
#   - 147956_4600.json
#   - 147956_4700.json
#   - 147956_4800.json
#   - 147956_4900.json
#   - 147956_500.json
#   - 147956_5000.json
#   - 147956_5100.json
#   - 147956_5200.json
#   - 147956_5300.json
#   - 147956_5400.json
#   - 147956_5500.json
#   - 147956_5600.json
#   - 147956_5700.json
#   - 147956_5800.json
#   - 147956_5900.json
#   - 147956_600.json
#   - 147956_6000.json
#   - 147956_6100.json
#   - 147956_6200.json
#   - 147956_700.json
#   - 147956_800.json
#   - 147956_900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_1900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_2900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_3900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_4900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_5900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_6000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_6100.json
# Loaded 60 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (60, 22)
# Loaded 60 listings from 147956_6200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147956_900.json
# Found 13 files starting with '147957' in ../sources/listings/:
#   - 147957_0.json
#   - 147957_100.json
#   - 147957_1000.json
#   - 147957_1200.json
#   - 147957_1300.json
#   - 147957_200.json
#   - 147957_300.json
#   - 147957_400.json
#   - 147957_500.json
#   - 147957_600.json
#   - 147957_700.json
#   - 147957_800.json
#   - 147957_900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_1000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_1200.json
# Loaded 34 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (34, 22)
# Loaded 34 listings from 147957_1300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 147957_900.json
# Found 81 files starting with '184380' in ../sources/listings/:
#   - 184380_0.json
#   - 184380_100.json
#   - 184380_1000.json
#   - 184380_1100.json
#   - 184380_1200.json
#   - 184380_1300.json
#   - 184380_1400.json
#   - 184380_1600.json
#   - 184380_1700.json
#   - 184380_1800.json
#   - 184380_1900.json
#   - 184380_200.json
#   - 184380_2000.json
#   - 184380_2100.json
#   - 184380_2200.json
#   - 184380_2300.json
#   - 184380_2400.json
#   - 184380_2500.json
#   - 184380_2600.json
#   - 184380_2700.json
#   - 184380_2800.json
#   - 184380_2900.json
#   - 184380_300.json
#   - 184380_3000.json
#   - 184380_3100.json
#   - 184380_3200.json
#   - 184380_3300.json
#   - 184380_3400.json
#   - 184380_3500.json
#   - 184380_3600.json
#   - 184380_3700.json
#   - 184380_3800.json
#   - 184380_3900.json
#   - 184380_400.json
#   - 184380_4000.json
#   - 184380_4100.json
#   - 184380_4200.json
#   - 184380_4300.json
#   - 184380_4400.json
#   - 184380_4500.json
#   - 184380_4600.json
#   - 184380_4700.json
#   - 184380_4800.json
#   - 184380_4900.json
#   - 184380_500.json
#   - 184380_5000.json
#   - 184380_5100.json
#   - 184380_5200.json
#   - 184380_5300.json
#   - 184380_5400.json
#   - 184380_5500.json
#   - 184380_5600.json
#   - 184380_5700.json
#   - 184380_5800.json
#   - 184380_5900.json
#   - 184380_600.json
#   - 184380_6000.json
#   - 184380_6100.json
#   - 184380_6200.json
#   - 184380_6300.json
#   - 184380_6400.json
#   - 184380_6500.json
#   - 184380_6600.json
#   - 184380_6700.json
#   - 184380_6800.json
#   - 184380_6900.json
#   - 184380_700.json
#   - 184380_7000.json
#   - 184380_7100.json
#   - 184380_7200.json
#   - 184380_7300.json
#   - 184380_7400.json
#   - 184380_7500.json
#   - 184380_7600.json
#   - 184380_7700.json
#   - 184380_7800.json
#   - 184380_7900.json
#   - 184380_800.json
#   - 184380_8000.json
#   - 184380_8100.json
#   - 184380_900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_1900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_2900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_3000.json
# Loaded 100 listings
#
# ...
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_6900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7000.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7500.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7700.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_7900.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_800.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_8000.json
# Loaded 17 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (17, 22)
# Loaded 17 listings from 184380_8100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 184380_900.json
# Found 7 files starting with '187616' in ../sources/listings/:
#   - 187616_0.json
#   - 187616_100.json
#   - 187616_200.json
#   - 187616_300.json
#   - 187616_400.json
#   - 187616_500.json
#   - 187616_600.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_300.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 187616_500.json
# Loaded 60 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (60, 22)
# Loaded 60 listings from 187616_600.json
# Found 5 files starting with '248979' in ../sources/listings/:
#   - 248979_0.json
#   - 248979_100.json
#   - 248979_200.json
#   - 248979_300.json
#   - 248979_400.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 248979_0.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 248979_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 248979_200.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 248979_300.json
# Loaded 59 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (59, 22)
# Loaded 59 listings from 248979_400.json
# Found 2 files starting with '250564' in ../sources/listings/:
#   - 250564_0.json
#   - 250564_100.json
# Loaded 100 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (100, 22)
# Loaded 100 listings from 250564_0.json
# Loaded 54 listings
#
# Columns: ['property_id', 'airbnb_property_id', 'vrbo_property_id', 'listing_type', 'bedrooms', 'bathrooms', 'accommodates', 'rating', 'reviews', 'title', 'revenue_ltm', 'revenue_potential_ltm', 'occupancy_rate_ltm', 'average_daily_rate_ltm', 'days_available_ltm', 'market_id', 'market_name', 'currency', 'address_match_confidence', 'lat', 'lng', 'submarket']
#
# DataFrame shape: (54, 22)
# Loaded 54 listings from 250564_100.json
# 16684
