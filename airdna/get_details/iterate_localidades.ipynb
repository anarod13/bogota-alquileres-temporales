# %%
import pandas as pd
import import_ipynb

# %%
import get_bedrooms
import get_listing_type
import get_minimum_stay

# %%
def add_localidad(localidad):
    get_bedrooms.parse_buckets_json(localidad)
    get_listing_type.parse_buckets_json(localidad)
    get_minimum_stay.parse_buckets_json(localidad)
    print(f'Localidad {localidad} updated')

# %%
localidades = pd.read_csv('../sources/localidades.csv')['id']
localidades = localidades.astype('str')

for localidad in localidades:
    add_localidad(localidad)
# Out:
#         rent_size_1_bedroom  rent_size_2_bedroom  rent_size_3_bedroom  \
# id
# 142664                 2705                  303                  154
#
#         rent_size_4_bedroom  rent_size_5_bedroom
# id
# 142664                   26                   31
#        id  rent_min_stay_1_nights  rent_min_stay_2_nights  \
# 0  142664                    1905                     678
#
#    rent_min_stay_3_nights  rent_min_stay_4_nights  rent_min_stay_7_nights  \
# 0                     262                     130                      86
#
#    rent_min_stay_30_nights
# 0                      157
# Localidad 142664 updated
#         rent_size_1_bedroom  rent_size_2_bedroom  rent_size_3_bedroom  \
# id
# 248952                 2702                  303                  154
#
#         rent_size_4_bedroom  rent_size_5_bedroom
# id
# 248952                   26                   31
#        id  rent_min_stay_1_nights  rent_min_stay_2_nights  \
# ...
